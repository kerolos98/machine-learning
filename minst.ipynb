# %%
import tensorflow.compat.v2 as tf
from keras.datasets import mnist
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D,MaxPool2D,Dropout
from keras import backend as K

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
img_rows, img_cols = 28, 28
num_classes = 10
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
Mnist_model = Sequential()

# %%
Mnist_model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
Mnist_model.add(Conv2D(64, (3, 3), activation='relu'))
Mnist_model.add(Conv2D(20, kernel_size=(3, 3), activation='relu'))
Mnist_model.add(MaxPool2D(pool_size=(2, 2)))
Mnist_model.add(Flatten())
Mnist_model.add(Dense(30,'relu'))
Mnist_model.add(Dense(90,'relu'))
Mnist_model.add(Dense(128,'relu'))
Mnist_model.add(Dense(num_classes , activation='softmax'))

# %%
Mnist_model.compile(loss = keras.losses.sparse_categorical_crossentropy,optimizer = 'adam',metrics = ['accuracy'])

# %%
Mnist_model.fit(x_train, y_train,batch_size=100,epochs=6)
# Out:
# Epoch 1/6
# 600/600 [==============================] - 211s 352ms/step - loss: 0.2219 - accuracy: 0.9304
# Epoch 2/6
# 600/600 [==============================] - 211s 351ms/step - loss: 0.0609 - accuracy: 0.9812
# Epoch 3/6
# 600/600 [==============================] - 211s 351ms/step - loss: 0.0450 - accuracy: 0.9865
# Epoch 4/6
# 600/600 [==============================] - 210s 351ms/step - loss: 0.0345 - accuracy: 0.9892
# Epoch 5/6
# 600/600 [==============================] - 213s 355ms/step - loss: 0.0277 - accuracy: 0.9917
# Epoch 6/6
# 600/600 [==============================] - 214s 356ms/step - loss: 0.0229 - accuracy: 0.9927

# %%
Mnist_model.evaluate(x=x_test,y=y_test)
# Out:
# 313/313 [==============================] - 10s 32ms/step - loss: 0.0360 - accuracy: 0.9889
# [0.036039482802152634, 0.9889000058174133]
